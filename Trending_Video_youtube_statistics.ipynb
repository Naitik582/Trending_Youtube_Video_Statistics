# %% [markdown]
# <a href="https://colab.research.google.com/github/Naitik582/Trending_Youtube_Video_Statistics/blob/main/Trending_Video_youtube_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
import os

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c1b3745d-f37f-4168-aaf8-db309d1e2162" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1b3745d-f37f-4168-aaf8-db309d1e2162">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

zip_path = "/content/archive (3).zip"
extract_path = "/content/data"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extraction complete. Files are in:", extract_path)
# Out:
# Extraction complete. Files are in: /content/data

# %%
import os

files = os.listdir(extract_path)
print("Extracted files:", files)
# Out:
# Extracted files: ['GB_category_id.json', 'MXvideos.csv', 'JP_category_id.json', 'DE_category_id.json', 'KRvideos.csv', 'IN_category_id.json', 'RU_category_id.json', 'FRvideos.csv', 'CA_category_id.json', 'RUvideos.csv', 'FR_category_id.json', 'USvideos.csv', 'DEvideos.csv', 'CAvideos.csv', 'MX_category_id.json', 'INvideos.csv', 'GBvideos.csv', 'KR_category_id.json', 'JPvideos.csv', 'US_category_id.json']

# %%
for file, df in dfs.items():
    print(f"\nData from {file}:")
    display(df.head())
# Out:
# Data from MXvideos.csv:
#       video_id trending_date  \
# 0  SbOwzAl9ZfQ      17.14.11
# 1  klOV6Xh-DnI      17.14.11
# 2  6L2ZF7Qzsbk      17.14.11
# 3  hcY52MFWMDM      17.14.11
# 4  _OXDcGPVAa4      17.14.11
#
#                                                title  \
# 0                     CapÃ­tulo 12 | MasterChef 2017
# 1  ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2           LOUIS CKAGÃ - EL PULSO DE LA REPÃBLICA
# 3   Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
# 4           DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
#
#                channel_title  category_id              publish_time  \
# 0            MasterChef 2017           24  2017-11-13T06:06:22.000Z
# 1   Micky Contreras Martinez           22  2017-11-13T05:11:58.000Z
# 2  El Pulso De La RepÃºblica           25  2017-11-13T17:00:02.000Z
# 3                   Casanare           25  2017-11-13T03:47:10.000Z
# 4                      Musas           26  2017-11-13T19:17:48.000Z
#
# ...

# %%
import pandas as pd

for file, data in json_data.items():

    items = data.get("items", [])

    flat_data = []
    for item in items:
        flat_data.append({
            "id": item.get("id"),
            "title": item.get("snippet", {}).get("title"),
            "channelId": item.get("snippet", {}).get("channelId"),
            "assignable": item.get("snippet", {}).get("assignable"),
        })

    df = pd.DataFrame(flat_data)

    print(f"\nFlattened Data from {file}:")
    display(df.head())
# Out:
# Flattened Data from GB_category_id.json:
#    id             title                 channelId  assignable
# 0   1  Film & Animation  UCBR8-60-B28hp2BmDPdntcQ        True
# 1   2  Autos & Vehicles  UCBR8-60-B28hp2BmDPdntcQ        True
# 2  10             Music  UCBR8-60-B28hp2BmDPdntcQ        True
# 3  15    Pets & Animals  UCBR8-60-B28hp2BmDPdntcQ        True
# 4  17            Sports  UCBR8-60-B28hp2BmDPdntcQ        True
# Flattened Data from JP_category_id.json:
#    id             title                 channelId  assignable
# 0   1  Film & Animation  UCBR8-60-B28hp2BmDPdntcQ        True
# 1   2  Autos & Vehicles  UCBR8-60-B28hp2BmDPdntcQ        True
# 2  10             Music  UCBR8-60-B28hp2BmDPdntcQ        True
# 3  15    Pets & Animals  UCBR8-60-B28hp2BmDPdntcQ        True
# 4  17            Sports  UCBR8-60-B28hp2BmDPdntcQ        True
# Flattened Data from DE_category_id.json:
#    id             title                 channelId  assignable
# ...

# %%
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          32 non-null     object
#  1   title       32 non-null     object
#  2   channelId   32 non-null     object
#  3   assignable  32 non-null     bool
# dtypes: bool(1), object(3)
# memory usage: 932.0+ bytes
# None
#         id   title                 channelId assignable
# count   32      32                        32         32
# unique  32      31                         1          2
# top      1  Comedy  UCBR8-60-B28hp2BmDPdntcQ      False
# freq     1       2                        32         17
# id            0
# title         0
# channelId     0
# assignable    0
# dtype: int64

# %%
print("Duplicates before:", df.duplicated().sum())
df.drop_duplicates(inplace=True)
print("Duplicates after:", df.duplicated().sum())
# Out:
# Duplicates before: 0
# Duplicates after: 0

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")

if 'category' in df.columns:
    df['category'] = df['category'].str.strip().str.lower()

df.head()
# Out:
#    id             title                 channelid  assignable
# 0   1  Film & Animation  UCBR8-60-B28hp2BmDPdntcQ        True
# 1   2  Autos & Vehicles  UCBR8-60-B28hp2BmDPdntcQ        True
# 2  10             Music  UCBR8-60-B28hp2BmDPdntcQ        True
# 3  15    Pets & Animals  UCBR8-60-B28hp2BmDPdntcQ        True
# 4  17            Sports  UCBR8-60-B28hp2BmDPdntcQ        True

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns

Q1 = df[numeric_cols].quantile(0.25)
Q3 = df[numeric_cols].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[~((df[numeric_cols] < lower_bound) | (df[numeric_cols] > upper_bound)).any(axis=1)]

print("New dataset shape:", df.shape)
# Out:
# New dataset shape: (32, 4)

# %%
Hkj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bad97cb817aa> in <cell line: 0>()
# ----> 1 Hkj
#
# NameError: name 'Hkj' is not defined
